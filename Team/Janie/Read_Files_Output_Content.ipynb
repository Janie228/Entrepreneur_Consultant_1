# %%
import os
import sys
import re
import csv
import zipfile
import pandas as pd
import shutil

# %%
def extract_zip(_zip_path, _ofile):
    parent_path = os.path.split(_zip_path)[0]
    file = os.path.split(_zip_path)[1]

    try:
        # Get file name
        output_folder = os.path.splitext(file)[0]
        # Get output folder path
        output_path = os.path.join(parent_path, "ZIP", output_folder)
        backup_path = os.path.join("..","UNZIP/")
        # Read and extract all files to output folder and close object
        zip_obj = zipfile.ZipFile(_zip_path, 'r')
        zip_obj.extractall(output_path)
        zip_obj.close()
        # Move zip file to Unzip folder
        check_dir(backup_path, "c")
        shutil.move(_zip_path, backup_path + file)
        return output_path
    except Exception as e:
        _ofile.write("Exception occurred: {}".format(e) + "\n")  # Write error to text file

# %%
def check_dir(_file_path, _type):
    output_dir = os.path.split(_file_path)[0]
    if not os.path.exists(output_dir):
        exist = False
    else:
        exist = True
        
    if _type == "c":
        if not exist:
            os.makedirs(output_dir)
        return True
    elif _type == "d":
        if exist:
            shutil.rmtree(output_dir)
        return False
    else:
        return exist

# %%
def write_xcel2_txt(_file_name, _data, _ofile):
    df = pd.DataFrame(_data)
    if "metadata" in _file_name:
        # Print 1st 4 rows and 2 columns
        _ofile.write(str(df.iloc[0:3,0:2]))
    else:
        # Print 1st 4 rows and 5 columns
        _ofile.write(str(df.iloc[0:3,0:4]))
    _ofile.write("\n---------------------------------------\n")

# %%
def record_fileInfo(dir_path, output_path):
    # Read all files to list
    xList = [x for x in os.listdir(dir_path)]
    # If output dir doesn't exist, create dir
    check_dir(output_path, "c")
    
    # Open text file in APPEND mode (a, r - read, w -write)
    with open(output_path, "a") as xfile:
        # Loop thru the file list and write info to opened text file if criteria are met
        i = 5
        for x in xList:
            xfile.write(f'****************************************************************************\n')
            xfile.write(f'### {x} ###\n')  # Write file name to text file
            try:
                # Split the extension from the path and normalise it to lowercase.
                ext = os.path.splitext(x)[-1].lower()

                # If it doesn't have an extension, call self-function to see if it's a directory with files; 
                # else if it's csv, excel, or text files, read and write info to output text file
                if not ext:
                    record_fileInfo(dir_path + x + "/", output_path)                               
                elif ext == ".zip":
                    # Call extract zip function
                    zip_path = extract_zip(dir_path + x, xfile)
                    record_fileInfo(zip_path + "/", output_path)  
                elif ext == ".csv":
                    # Read CSV data to dataframe
                    csv = pd.read_csv(dir_path + x) 
                    write_xcel2_txt(x, csv, xfile)  

                elif ext == ".xls" or ext == ".xlsx":  
                    xlx = pd.read_excel(dir_path + x)   # Read excel data 
                    write_xcel2_txt(x, xlx, xfile)  

                elif ext == ".txt":
                    with open(dir_path + x, "r") as page:
                        for line in page:
                            if i > 0:
                                xfile.write(str(line.strip()) + "\n")
                                i -= 1
                            else:
                                break
            except Exception as e:
                xfile.write("Exception occurred: {}".format(e) + "\n")  # Write error to text file

# %%
# Get all files from directory Resources
excel_path = ".\Zip\Zip\CIUS2015downloadablefiles\CIUS2015datatables"  #os.path.join(".", "Zip", "Zip")
output_path = os.path.join(".", "Output", "resource_output.txt")
record_fileInfo(excel_path + '/', output_path)

# Open output file & print result
print(open(output_path).read())
# Out:
# ### aff_download_readme_ann.txt ###
# ****************************************************************************
# ### household.csv ###
#       CONTROL  TOTROOMS TOTHCAMT  PERPOVLVL
# 0  '11000001'         8     '14'        501
# 1  '11000002'         7     '15'        501
# 2  '11000005'         8     '12'        501
# ---------------------------------------
# ****************************************************************************
# ### person.csv ###
#       CONTROL JAGE JCITSHP JENROLL
# 0  '11000001'  '0'     '0'     '0'
# 1  '11000001'  '0'     '0'     '0'
# 2  '11000001'  '0'     '0'     '0'
# ---------------------------------------
# ****************************************************************************
# ### project.csv ###
#       CONTROL JJOBCOMP JJOBCOMPYR JJOBCOST
# 0  '11000001'      '0'        '0'      '0'
# 1  '11000002'      '0'        '0'      '0'
# 2  '11000002'      '0'        '0'      '0'
# ---------------------------------------
# ****************************************************************************
# ### tab10datadec_final.pdf ###
# ****************************************************************************
# ### tab11datadec_final.pdf ###
# ****************************************************************************
# ### tab12datadec_final.pdf ###
# ****************************************************************************
# ### tab13datadec_final.pdf ###
# ****************************************************************************
# ### tab14datadec_final.pdf ###
# ****************************************************************************
# ### tab15datadec_final.pdf ###
# ****************************************************************************
# ### tab16datadec_final.pdf ###
# ****************************************************************************
# ### tab17datadec_final.pdf ###
# ****************************************************************************
# ### tab18datadec_final.pdf ###
# ****************************************************************************
# ### tab19datadec_final.pdf ###
# ****************************************************************************
# ### tab1datadec_final.pdf ###
# ****************************************************************************
# ### tab1overview_final.pdf ###
# ****************************************************************************
# ### tab20datadec_final.pdf ###
# ****************************************************************************
# ### tab21datadec_final.pdf ###
# ****************************************************************************
# ### tab22datadec_final.pdf ###
# ****************************************************************************
# ### tab23datadec_final.pdf ###
# ****************************************************************************
# ### tab24datadec_final.pdf ###
# ****************************************************************************
# ### tab25datadec_final.pdf ###
# ****************************************************************************
# ### tab26datadec_final.pdf ###
# ****************************************************************************
# ### tab27datadec_final.pdf ###
# ****************************************************************************
# ### tab28datadec_final.pdf ###
# ****************************************************************************
# ### tab29datadec_final.pdf ###
# ****************************************************************************
# ### tab2datadec_final.pdf ###
# ****************************************************************************
# ### tab2overview_final.pdf ###
# ****************************************************************************
# ### tab30datadec_final.pdf ###
# ****************************************************************************
# ### tab31datadec_final.pdf ###
# ****************************************************************************
# ### tab32datadec_final.pdf ###
# ****************************************************************************
# ### tab32overview_final.pdf ###
# ****************************************************************************
# ### tab33datadec_final.pdf ###
# ****************************************************************************
# ### tab33overview_final.pdf ###
# ****************************************************************************
# ### tab34datadec_final.pdf ###
# ****************************************************************************
# ### tab34overview_final.pdf ###
# ****************************************************************************
# ### tab35datadec_final.pdf ###
# ****************************************************************************
# ### tab35overview_final.pdf ###
# ****************************************************************************
# ### tab36datadec_final.pdf ###
# ****************************************************************************
# ### tab36overview_final.pdf ###
# ****************************************************************************
# ### tab37datadec_final.pdf ###
# ****************************************************************************
# ### tab37overview_final.pdf ###
# ****************************************************************************
# ### tab38datadec_final.pdf ###
# ****************************************************************************
# ### tab38overview_final.pdf ###
# ****************************************************************************
# ### tab39datadec_final.pdf ###
# ****************************************************************************
# ### tab39overview_final.pdf ###
# ****************************************************************************
# ### tab3datadec_final.pdf ###
# ****************************************************************************
# ### tab3overview_final.pdf ###
# ****************************************************************************
# ### tab40datadec_final.pdf ###
# ****************************************************************************
# ### tab40overview_final.pdf ###
# ****************************************************************************
# ### tab41datadec_final.pdf ###
# ****************************************************************************
# ### tab41overview_final.pdf ###
# ****************************************************************************
# ### tab42datadec_final.pdf ###
# ****************************************************************************
# ### tab42overview_final.pdf ###
# ****************************************************************************
# ### tab43datadec_final.pdf ###
# ****************************************************************************
# ### tab43overview_final.pdf ###
# ****************************************************************************
# ### tab44datadec_final.pdf ###
# ****************************************************************************
# ### tab45datadec_final.pdf ###
# ****************************************************************************
# ### tab46datadec_final.pdf ###
# ****************************************************************************
# ### tab47datadec_final.pdf ###
# ****************************************************************************
# ### tab48datadec_final.pdf ###
# ****************************************************************************
# ### tab49datadec_final.pdf ###
# ****************************************************************************
# ### tab4datadec_final.pdf ###
# ****************************************************************************
# ### tab4overview_final.pdf ###
# ****************************************************************************
# ### tab50datadec_final.pdf ###
# ****************************************************************************
# ### tab51datadec_final.pdf ###
# ****************************************************************************
# ### tab52datadec_final.pdf ###
# ****************************************************************************
# ### tab53datadec_final.pdf ###
# ****************************************************************************
# ### tab54datadec_final.pdf ###
# ****************************************************************************
# ### tab55datadec_final.pdf ###
# ****************************************************************************
# ### tab56datadec_final.pdf ###
# ****************************************************************************
# ### tab57datadec_final.pdf ###
# ****************************************************************************
# ### tab58datadec_final.pdf ###
# ****************************************************************************
# ### tab59datadec_final.pdf ###
# ****************************************************************************
# ### tab5datadec_final.pdf ###
# ****************************************************************************
# ### tab60datadec_final.pdf ###
# ****************************************************************************
# ### tab61datadec_final.pdf ###
# ****************************************************************************
# ### tab62datadec_final.pdf ###
# ****************************************************************************
# ### tab63datadec_final.pdf ###
# ****************************************************************************
# ### tab64datadec_final.pdf ###
# ****************************************************************************
# ### tab65datadec_final.pdf ###
# ****************************************************************************
# ### tab66datadec_final.pdf ###
# ****************************************************************************
# ### tab67datadec_final.pdf ###
# ****************************************************************************
# ### tab68datadec_final.pdf ###
# ****************************************************************************
# ### tab69datadec_final.pdf ###
# ****************************************************************************
# ### tab6datadec_final.pdf ###
# ****************************************************************************
# ### tab70datadec_final.pdf ###
# ****************************************************************************
# ### tab70overview_final.pdf ###
# ****************************************************************************
# ### tab71datadec_final.pdf ###
# ****************************************************************************
# ### tab71overview_final.pdf ###
# ****************************************************************************
# ### tab72datadec_final.pdf ###
# ****************************************************************************
# ### tab73datadec_final.pdf ###
# ****************************************************************************
# ### tab74datadec_final.pdf ###
# ****************************************************************************
# ### tab74overview_final.pdf ###
# ****************************************************************************
# ### tab75datadec_final.pdf ###
# ****************************************************************************
# ### tab75overview_final.pdf ###
# ****************************************************************************
# ### tab76datadec_final.pdf ###
# ****************************************************************************
# ### tab77datadec_final.pdf ###
# ****************************************************************************
# ### tab78datadec_final.pdf ###
# ****************************************************************************
# ### tab79datadec_final.pdf ###
# ****************************************************************************
# ### tab7datadec_final.pdf ###
# ****************************************************************************
# ### tab80datadec_final.pdf ###
# ****************************************************************************
# ### tab81datadec_final.pdf ###
# ****************************************************************************
# ### tab8datadec_final.pdf ###
# ****************************************************************************
# ### tab9datadec_final.pdf ###
# ****************************************************************************
# ### Aggravated_Assault_Table_Aggravated_Assault_Types_of_Weapons_Used_Percent_Distribution_by_Region_2015.xls ###
#                    Aggravated Assault Table             Unnamed: 1 Unnamed: 2  \
# 0  Aggravated Assault, Types of Weapons Used                   NaN        NaN
# 1       Percent Distribution by Region, 2015                   NaN        NaN
# 2                                     Region  Total all \nweapons1   Firearms
#
#                           Unnamed: 3
# 0                                NaN
# 1                                NaN
# 2  Knives or \ncutting \ninstruments
# ---------------------------------------
# ****************************************************************************
# ### Arson_Table_1_Arson_Rate_by_Population_Group_2015.xls ###
#                                        Arson Table 1 Unnamed: 1
# 0                                         Arson Rate        NaN
# 1                          by Population Group, 2015        NaN
# 2  [13,443 agencies; 2015 estimated population 27...        NaN
# ---------------------------------------
# ****************************************************************************
# ### Arson_Table_2_Arson_by_Type_of_Property_2015.xls ###
#                                       Arson Table 2  Unnamed: 1 Unnamed: 2  \
# 0                                              Arson        NaN        NaN
# 1                          by Type of Property, 2015        NaN        NaN
# 2  [14,986 agencies; 2015 estimated population 26...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Expanded_Homicide_Data_Table_10_Murder_Circumstances_by_Relationship_2015.xls ###
#   Expanded Homicide Data Table 10              Unnamed: 1 Unnamed: 2  \
# 0            Murder Circumstances                     NaN        NaN
# 1          by Relationship,1 2015                                NaN
# 2                   Circumstances  Total\nmurder\nvictims    Husband
#
#   Unnamed: 3
# 0
# 1        NaN
# 2       Wife
# ---------------------------------------
# ****************************************************************************
# ### Expanded_Homicide_Data_Table_11_Murder_Circumstances_by_Weapon_2015.xls ###
#   Expanded Homicide Data Table 11              Unnamed: 1       Unnamed: 2  \
# 0            Murder Circumstances                     NaN              NaN
# 1                 by Weapon, 2015
# 2                   Circumstances  Total\nmurder\nvictims  Total\nfirearms
#
#
# 0
# 1       NaN
# 2  Handguns
# ---------------------------------------
# ****************************************************************************
# ### Expanded_Homicide_Data_Table_12_Murder_Circumstances_2011-2015.xls ###
#    Expanded Homicide Data Table 12  Unnamed: 1  Unnamed: 2  Unnamed: 3
# 0  Murder Circumstances, 2011–2015         NaN         NaN         NaN
# 1                    Circumstances      2011.0      2012.0     20131.0
# 2                            Total     12795.0     12888.0     12253.0
# ---------------------------------------
# ****************************************************************************
# ### Expanded_Homicide_Data_Table_13_Murder_Circumstances_by_Sex_of_Victim_2015.xls ###
#   Expanded Homicide Data Table 13              Unnamed: 1 Unnamed: 2  \
# 0            Murder Circumstances                     NaN        NaN
# 1          by Sex of Victim, 2015
# 2                   Circumstances  Total\nmurder\nvictims       Male
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2     Female
# ---------------------------------------
# ****************************************************************************
# ### Expanded_Homicide_Data_Table_14_Justifiable_Homicide_by_Weapon_Law_Enforcement_2011-2015.xls ###
#           Expanded Homicide Data Table 14 Unnamed: 1       Unnamed: 2  \
# 0                    Justifiable Homicide        NaN              NaN
# 1  by Weapon, Law Enforcement,1 2011–2015        NaN              NaN
# 2                                    Year      Total  Total\nfirearms
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2   Handguns
# ---------------------------------------
# ****************************************************************************
# ### Expanded_Homicide_Data_Table_15_Justifiable_Homicide_by_Weapon_Private_Citizen_2011-2015.xls ###
#           Expanded Homicide Data Table 15 Unnamed: 1       Unnamed: 2  \
# 0                    Justifiable Homicide        NaN              NaN
# 1  by Weapon, Private Citizen,1 2011–2015        NaN              NaN
# 2                                    Year      Total  Total\nfirearms
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2   Handguns
# ---------------------------------------
# ****************************************************************************
# ### Expanded_Homicide_Data_Table_1_Murder_Victims_by_Race_Ethnicity_and_Sex_2015.xls ###
#       Expanded Homicide Data Table 1 Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0                     Murder Victims        NaN        NaN        NaN
# 1  by Race, Ethnicity, and Sex, 2015        NaN        NaN        NaN
# 2                               Race      Total       Sex         NaN
# ---------------------------------------
# ****************************************************************************
# ### Expanded_Homicide_Data_Table_2_Murder_Victims_by_Age_Sex_and_Race_2015.xls ###
#            Expanded Homicide Data Table 2 Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0                          Murder Victims        NaN        NaN        NaN
# 1  by Age, Sex, Race, and Ethnicity, 2015        NaN        NaN        NaN
# 2                                     Age      Total       Sex         NaN
# ---------------------------------------
# ****************************************************************************
# ### Expanded_Homicide_Data_Table_3_Murder_Offenders_by_Age_Sex_and_Race_2015.xls ###
#            Expanded Homicide Data Table 3 Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0                        Murder Offenders        NaN        NaN        NaN
# 1  by Age, Sex, Race, and Ethnicity, 2015        NaN        NaN        NaN
# 2                                     Age      Total       Sex         NaN
# ---------------------------------------
# ****************************************************************************
# ### Expanded_Homicide_Data_Table_4_Murder_by_Victim_Offender_Situations_2015.xls ###
#         Expanded Homicide Data Table 4 Unnamed: 1              Unnamed: 2  \
# 0                              Murder         NaN                     NaN
# 1  by Victim/Offender Situations, 2015        NaN                     NaN
# 2                            Situation      Total  Percent\ndistribution1
#
#    Unnamed: 3
# 0         NaN
# 1         NaN
# 2         NaN
# ---------------------------------------
# ****************************************************************************
# ### Expanded_Homicide_Data_Table_5_Murder_Age_of_Victim_by_Age_of_Offender_2015.xls ###
#            Expanded Homicide Data Table 5 Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0                                 Murder         NaN        NaN        NaN
# 1  Age of Victim by Age of Offender, 2015        NaN        NaN        NaN
# 2         [Single victim/single offender]        NaN        NaN        NaN
# ---------------------------------------
# ****************************************************************************
# ### Expanded_Homicide_Data_Table_6_Murder_Race_and_Sex_of_Vicitm_by_Race_and_Sex_of_Offender_2015.xls ###
#                       Expanded Homicide Data Table 6 Unnamed: 1 Unnamed: 2  \
# 0                                            Murder         NaN        NaN
# 1  Race, Ethnicity, and Sex of Victim by Race, Et...        NaN        NaN
# 2                    [Single victim/single offender]        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN  ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_Alabama_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                            ALABAMA        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_Arizona_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                            ARIZONA        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_Arkansas_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                           ARKANSAS        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_California_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                         CALIFORNIA        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_Colorado_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                           COLORADO        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_Delaware_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                           DELAWARE        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_Florida_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                            FLORIDA        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_Georgia_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                            GEORGIA        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_Hawaii_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                            HAWAII         NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_Idaho_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                              IDAHO        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_Illinois_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                           ILLINOIS        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_Indiana_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                            INDIANA        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_Iowa_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                               IOWA        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_Kansas_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                             KANSAS        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_Kentucky_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                           KENTUCKY        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_Louisiana_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                          LOUISIANA        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_Maine_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                              MAINE        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_Maryland_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                           MARYLAND        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_Michigan_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                           MICHIGAN        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_Minnesota_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                          MINNESOTA        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_Mississippi_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                        MISSISSIPPI        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_Missouri_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                           MISSOURI        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_Montana_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                            MONTANA        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_Nebraska_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                           NEBRASKA        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_Nevada_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                             NEVADA        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_New Hampshire_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                      NEW HAMPSHIRE        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_New_Jersey_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                        NEW JERSEY1        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_New_Mexico_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                         NEW MEXICO        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_New_York_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                           NEW YORK        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_North_Carolina_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                     NORTH CAROLINA        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_North_Dakota_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                       NORTH DAKOTA        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_Ohio_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                               OHIO        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_Oklahoma_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                           OKLAHOMA        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_Oregon_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                             OREGON        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_Pennsylvania_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                       PENNSYLVANIA        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_South_Carolina_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                     SOUTH CAROLINA        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_South_Dakota_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                       SOUTH DAKOTA        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_Tennessee_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                          TENNESSEE        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_Texas_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                              TEXAS        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_Utah_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                               UTAH        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_Vermont_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                            VERMONT        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_Virginia_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                           VIRGINIA        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_Washington_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                         WASHINGTON        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_West_Virginia_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                      WEST VIRGINIA        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_Wisconsin_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                          WISCONSIN        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_10_Offenses_Known_to_Law_Enforcement_Wyoming_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 10 Unnamed: 1 Unnamed: 2  \
# 0                                            WYOMING        NaN        NaN
# 1                  Offenses Known to Law Enforcement        NaN        NaN
# 2  by Metropolitan and Nonmetropolitan Counties, ...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_11_Offenses_Known_to_Law_Enforcement_Alabama_by_State_Tribal_and_Other_Agencies_2015.xls ###
# ...
#                    Table 60 Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0                   Arrests        NaN                   NaN
# 1  Nonmetropolitan Counties                   NaN        NaN
# 2              by Sex, 2015        NaN        NaN        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_61A_Arrests_Nonmetropolitan_Counties_by_Race_and_Ethnicity_2015.xls ###
#                      Table 61A Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0                      Arrests        NaN        NaN        NaN
# 1     Nonmetropolitan Counties        NaN        NaN        NaN
# 2  by Race and Ethnicity, 2015        NaN        NaN        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_61B_Arrests_Nonmetropolitan_Counties_by_Race_and_Ethnicity_2015_Continued.xls ###
#                                Table 61B Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0                                Arrests        NaN        NaN        NaN
# 1               Nonmetropolitan Counties        NaN                   NaN
# 2  by Race and Ethnicity, 2015-Continued        NaN        NaN        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_61C_Arrests_Nonmetropoltian_Counties_by_Race_and_Ethnicity_2015_Continued.xls ###
#                                Table 61C Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0                                Arrests        NaN        NaN        NaN
# 1               Nonmetropolitan Counties        NaN
# 2  by Race and Ethnicity, 2015-Continued        NaN        NaN        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_62_Arrest_Trends_Suburban_Areas_2015.xls ###
#                                             Table 62 Unnamed: 1  Unnamed: 2  \
# 0                                      Arrest Trends        NaN         NaN
# 1                         Suburban Areas,1 2014–2015        NaN         NaN
# 2  [6,241 agencies; 2015 estimated population 99,...        NaN         NaN
#
#   Unnamed: 3
# 0        NaN
# 1
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_63_Arrest_Trends_Suburban_Areas_by_Sex_2015.xls ###
#             Table 63 Unnamed: 1  Unnamed: 2 Unnamed: 3
# 0      Arrest Trends        NaN         NaN        NaN
# 1    Suburban Areas1        NaN         NaN        NaN
# 2  by Sex, 2014–2015        NaN         NaN        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_64_Arrests_Suburban_Areas_by_Age_2015.xls ###
#           Table 64 Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0          Arrests        NaN        NaN        NaN
# 1  Suburban Areas1        NaN        NaN        NaN
# 2     by Age, 2015        NaN        NaN        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_65_Arrests_Suburban_Areas_Persons_Under_15_18_21_and_25_Years_of_Age_2015.xls ###
#                                             Table 65 Unnamed: 1 Unnamed: 2  \
# 0                                            Arrests        NaN        NaN
# 1                                    Suburban Areas1        NaN        NaN
# 2  Persons Under 15, 18, 21, and 25 Years of Age,...        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_66_Arrests_Suburban_Areas_by_Sex_2015.xls ###
#           Table 66 Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0          Arrests        NaN        NaN        NaN
# 1  Suburban Areas1        NaN        NaN        NaN
# 2    by Sex, 2015         NaN        NaN        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_67A_Arrests_Suburban_Areas_by_Race_and_Ethnicity_2015.xls ###
#                       Table 67A Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0                       Arrests        NaN        NaN        NaN
# 1              Suburban Areas1         NaN        NaN        NaN
# 2  by Race and Ethnicity, 2015         NaN        NaN        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_67B_Arrests_Suburban_Areas_by_Race_and_Ethnicity_2015_Continued.xls ###
#                                Table 67B Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0                                Arrests        NaN        NaN        NaN
# 1                        Suburban Areas1        NaN        NaN        NaN
# 2  by Race and Ethnicity, 2015-Continued        NaN        NaN        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_67C_Arrests_Suburban_Areas_by_Race_and_Ethnicity_2015_Continued.xls ###
#                                Table 67C Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0                                Arrests        NaN        NaN        NaN
# 1                       Suburban Areas1         NaN                   NaN
# 2  by Race and Ethnicity, 2015-Continued        NaN        NaN        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_68_Police_Disposition_Juvenile_Offenders_Taken_into_Custody_2015.xls ###
#                                       Table 68 Unnamed: 1 Unnamed: 2  \
# 0                           Police Disposition        NaN        NaN
# 1  Juvenile Offenders Taken into Custody, 2015        NaN        NaN
# 2                  [2015 estimated population]        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_69_Arrest_by_State_2015.xls ###
#          Table 69 Unnamed: 1             Unnamed: 2       Unnamed: 3
# 0        Arrests         NaN                    NaN              NaN
# 1  by State, 2015                                                NaN
# 2           State        NaN  Total\nall \nclasses1  Violent\ncrime2
# ---------------------------------------
# ****************************************************************************
# ### Table_6_Crime_in_the_United_States_by_Metropolitan_Statistical_Area_2015.xls ###
#                                   Table 6                 Unnamed: 1  \
# 0              Crime in the United States                        NaN
# 1  by Metropolitan Statistical Area, 2015                        NaN
# 2           Metropolitan Statistical Area  Counties/principal cities
#
#    Unnamed: 2      Unnamed: 3
# 0         NaN             NaN
# 1         NaN             NaN
# 2  Population  Violent\ncrime
# ---------------------------------------
# ****************************************************************************
# ### Table_70_Full_time_Law_Enforcement_Employees_by_Region_and_Geographic_Division_by_Rate_2015.xls ###
#                                             Table 70 Unnamed: 1 Unnamed: 2  \
# 0               Full-time Law Enforcement Employees1        NaN
# 1  by Region and Geographic Division by Populatio...        NaN
# 2        Number and Rate per 1,000 Inhabitants, 2015        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_71_Full_time_Law_Enforcement_Officers_by_Region_and_Geographic_Division_by_Rate_2015.xls ###
#                                             Table 71 Unnamed: 1 Unnamed: 2  \
# 0                Full-time Law Enforcement Officers         NaN        NaN
# 1  by Region and Geographic Division by Populatio...        NaN
# 2        Number and Rate per 1,000 Inhabitants, 2015        NaN        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_72_Full_time_Law_Enforcement_Employees_Range_in_Rate_per_1000_Inhabitants_by_Population_Group_2015.xls ###
#                                 Table 72 Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0  Full-time Law Enforcement Employees1         NaN        NaN        NaN
# 1   Range in Rate per 1,000 Inhabitants         NaN        NaN        NaN
# 2              by Population Group, 2015        NaN        NaN        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_73_Full_time_Law_Enforcement_Officers_Range_in_Rate_per_1000_Inhabitants_by_Population_Group_2015.xls ###
#                                Table 73 Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0   Full-time Law Enforcement Officers         NaN        NaN        NaN
# 1  Range in Rate per 1,000 Inhabitants         NaN        NaN        NaN
# 2             by Population Group, 2015        NaN        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_74_Full_time_Law_Enforcement_Employees_by_Population_Group_Percent_Male_and_Female_2015.xls ###
#                                Table 74 Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0  Full-time Law Enforcement Employees         NaN        NaN        NaN
# 1                   by Population Group        NaN        NaN        NaN
# 2         Percent Male and Female, 2015        NaN        NaN        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_75_Full_time_Law_Enforcement_Employees_by_Population_Group_Percent_of_Total_2015.xls ###
#                                         Table 75 Unnamed: 1 Unnamed: 2  \
# 0  Full-time Civilian Law Enforcement Employees         NaN        NaN
# 1                            by Population Group        NaN        NaN
# 2                         Percent of Total, 2015                   NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_76_Full_time_State_Law_Enforcement_Employees_by_state_2015.xls ###
#                                      Table 76 Unnamed: 1  \
# 0  Full-time State Law Enforcement Employees         NaN
# 1                              by State, 2015        NaN
# 2                                       State     Agency
#
#                           Unnamed: 2        Unnamed: 3
# 0                                NaN               NaN
# 1                                NaN               NaN
# 2  Total law\nenforcement\nemployees  Total \nofficers
# ---------------------------------------
# ****************************************************************************
# ### Table_77_Full_time_Law_Enforcement_Employess_by_State_2015.xls ###
#                               Table 77                         Unnamed: 1  \
# 0  Full-time Law Enforcement Employees                                NaN
# 1                       by State, 2015                                NaN
# 2                                State  Total law\nenforcement\nemployees
#
#         Unnamed: 2 Unnamed: 3
# 0              NaN        NaN
# 1              NaN        NaN
# 2  Total\nofficers        NaN
# ---------------------------------------
# ****************************************************************************
# ### Table_78_Full_time_Law_Enforcement_Employees_by_State_by_Cities_2015.xls ###
#                               Table 78 Unnamed: 1  Unnamed: 2  \
# 0  Full-time Law Enforcement Employees        NaN         NaN
# 1                        by City, 2015        NaN         NaN
# 2                                State       City  Population
#
#                           Unnamed: 3
# 0                                NaN
# 1                                NaN
# 2  Total law\nenforcement\nemployees
# ---------------------------------------
# ****************************************************************************
# ### Table_79_Full_time_Law_Enforcement_Employees_by_State_by_University_and_College_2015.xls ###
#                               Table 79           Unnamed: 1 Unnamed: 2  \
# 0  Full-time Law Enforcement Employees                  NaN        NaN
# 1      by University and College, 2015                  NaN        NaN
# 2                                State  University/College      Campus
#
#              Unnamed: 3
# 0                   NaN
# 1                   NaN
# 2  Student\nenrollment1
# ---------------------------------------
# ****************************************************************************
# ### Table_7_Offense_Analysis_United_States_2011-2015.xls ###
#                     Table 7 Unnamed: 1  Unnamed: 2  Unnamed: 3
# 0          Offense Analysis        NaN         NaN         NaN
# 1  United States, 2011–2015        NaN         NaN         NaN
# 2            Classification        NaN      2011.0      2012.0
# ---------------------------------------
# ****************************************************************************
# ### Table_80_Full_time_Law_Enforcement_Employees_by_State_by_Metropolitan_and_Nonmetropolitan_Counties_2015.xls ###
#                                             Table 80 Unnamed: 1  \
# 0               Full-time Law Enforcement Employees         NaN
# 1  by State by Metropolitan and Nonmetropolitan C...        NaN
# 2                                              State     County
#
#                           Unnamed: 2       Unnamed: 3
# 0                                NaN              NaN
# 1                                NaN              NaN
# 2  Total law\nenforcement\nemployees  Total\nofficers
# ---------------------------------------
# ****************************************************************************
# ### Table_81_Full_time_Law_Enforcement_Empolyees_by_State_by_State_Tribal_and_Other_Agencies_2015.xls ###
#                                             Table 81  \
# 0                Full-time Law Enforcement Employees
# 1  by State by State, Tribal, and Other Agencies,...
# 2                                              State
#
#                   Unnamed: 1   Unnamed: 2                         Unnamed: 3
# 0                        NaN          NaN                                NaN
# 1                        NaN          NaN                                NaN
# 2  State/Tribal/Other Agency  Unit/Office  Total law\nenforcement\nemployees
# ---------------------------------------
# ****************************************************************************
# ### Table_8_Offenses_Known_to_Law_Enforcement_by_State_by_City_2015.xls ###
#                              Table 8 Unnamed: 1  Unnamed: 2      Unnamed: 3
# 0  Offenses Known to Law Enforcement        NaN         NaN             NaN
# 1             by State by City, 2015        NaN         NaN             NaN
# 2                              State       City  Population  Violent\ncrime
# ---------------------------------------
# ****************************************************************************
# ### Table_9_Offenses_Known_to_Law_Enforcement_by_State_by_University_and_College_2015.xls ###
#                                     Table 9           Unnamed: 1 Unnamed: 2  \
# 0        Offenses Known to Law Enforcement                   NaN        NaN
# 1  by State by University and College, 2015                  NaN        NaN
# 2                                     State  University/College      Campus
#
#              Unnamed: 3
# 0                   NaN
# 1                   NaN
# 2  Student\nenrollment1
# ---------------------------------------
