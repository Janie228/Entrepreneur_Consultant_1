# %%
import pandas as pd

# %%
state_info_2017_df = pd.read_csv("ACS_17_5YR_S0102_with_ann.csv", skiprows=[0])
state_info_2016_df = pd.read_csv("ACS_16_5YR_S0102_with_ann.csv", skiprows=[0])
state_info_2015_df = pd.read_csv("ACS_15_5YR_S0102_with_ann.csv", skiprows=[0])
state_info_2014_df = pd.read_csv("ACS_14_5YR_S0102_with_ann.csv", skiprows=[0])
state_info_2013_df = pd.read_csv("ACS_13_5YR_S0102_with_ann.csv", skiprows=[0])

state_info_2013_df.head()
# Out:
#             Id  Id2   Geography  Total; Estimate; Total population  \
# 0  0400000US01    1     Alabama                            4799277
# 1  0400000US02    2      Alaska                             720316
# 2  0400000US04    4     Arizona                            6479703
# 3  0400000US05    5    Arkansas                            2933369
# 4  0400000US06    6  California                           37659181
#
#   Total; Margin of Error; Total population  \
# 0                                    *****
# 1                                    *****
# 2                                    *****
# 3                                    *****
# 4                                    *****
#
#    60 years and over; Estimate; Total population  \
# 0                                         966454
# 1                                          96430
# 2                                        1294109
# 3                                         601493
# 4                                        6360929
#
#    60 years and over; Margin of Error; Total population  \
# 0                                               2674
# 1                                                985
# 2                                               3052
# 3                                               2218
# 4                                               7359
#
#    Total; Estimate; SEX AND AGE - Male  \
# 0                                 48.5
# 1                                 52.2
# 2                                 49.7
# 3                                 49.1
# 4                                 49.7
#
#    Total; Margin of Error; SEX AND AGE - Male  \
# 0                                         0.1
# 1                                         0.1
# 2                                         0.1
# 3                                         0.1
# 4                                         0.1
#
#    60 years and over; Estimate; SEX AND AGE - Male  \
# 0                                             44.1
# 1                                             50.3
# 2                                             46.1
# 3                                             44.9
# 4                                             45.0
#
#                                        ...                                       \
# 0                                      ...
# 1                                      ...
# 2                                      ...
# 3                                      ...
# 4                                      ...
#
#    60 years and over; Estimate; Renter-occupied housing units - GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - Less than 30 percent  \
# 0                                               56.0
# 1                                               52.6
# 2                                               46.1
# 3                                               58.1
# 4                                               40.2
#
#    60 years and over; Margin of Error; Renter-occupied housing units - GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - Less than 30 percent  \
# 0                                                1.0
# 1                                                2.7
# 2                                                0.9
# 3                                                1.3
# 4                                                0.3
#
#    Total; Estimate; Renter-occupied housing units - GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - 30 percent or more  \
# 0                                               44.8
# 1                                               40.6
# 2                                               47.5
# 3                                               43.0
# 4                                               54.1
#
#    Total; Margin of Error; Renter-occupied housing units - GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - 30 percent or more  \
# 0                                                0.6
# 1                                                0.9
# 2                                                0.4
# 3                                                0.6
# 4                                                0.2
#
#    60 years and over; Estimate; Renter-occupied housing units - GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - 30 percent or more  \
# 0                                               44.0
# 1                                               47.4
# 2                                               53.9
# 3                                               41.9
# 4                                               59.8
#
#    60 years and over; Margin of Error; Renter-occupied housing units - GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - 30 percent or more  \
# 0                                                1.0
# 1                                                2.7
# 2                                                0.9
# 3                                                1.3
# 4                                                0.3
#
#    Total; Estimate; GROSS RENT - Median gross rent (dollars)  \
# 0                                                705
# 1                                               1098
# 2                                                896
# 3                                                661
# 4                                               1224
#
#    Total; Margin of Error; GROSS RENT - Median gross rent (dollars)  \
# 0                                                  3
# 1                                                 13
# 2                                                  4
# 3                                                  4
# 4                                                  2
#
#    60 years and over; Estimate; GROSS RENT - Median gross rent (dollars)  \
# 0                                                569
# 1                                                846
# 2                                                836
# 3                                                565
# 4                                                994
#
#    60 years and over; Margin of Error; GROSS RENT - Median gross rent (dollars)
# 0                                                  9
# 1                                                 23
# 2                                                  8
# 3                                                  9
# 4                                                  4
#
# [5 rows x 427 columns]

# %%
demo_state_cols_2017_df = state_info_2017_df.filter(regex="RACE AND HISPANIC OR LATINO ORIGIN")
demo_state_2017_df = state_info_2017_df.filter(regex="Geography")
demo_state_cols_2016_df = state_info_2016_df.filter(regex="RACE AND HISPANIC OR LATINO ORIGIN")
demo_state_2016_df = state_info_2016_df.filter(regex="Geography")
demo_state_cols_2015_df = state_info_2015_df.filter(regex="RACE AND HISPANIC OR LATINO ORIGIN")
demo_state_2015_df = state_info_2015_df.filter(regex="Geography")
demo_state_cols_2014_df = state_info_2014_df.filter(regex="RACE AND HISPANIC OR LATINO ORIGIN")
demo_state_2014_df = state_info_2014_df.filter(regex="Geography")
demo_state_cols_2013_df = state_info_2013_df.filter(regex="RACE AND HISPANIC OR LATINO ORIGIN")
demo_state_2013_df = state_info_2013_df.filter(regex="Geography")

demo_state_cols_2013_df.head()
demo_state_2013_df.head()
# Out:
#     Geography
# 0     Alabama
# 1      Alaska
# 2     Arizona
# 3    Arkansas
# 4  California

# %%
total_demo_state_2017_df = pd.concat([demo_state_2017_df, demo_state_cols_2017_df], axis=1)
total_demo_state_2016_df = pd.concat([demo_state_2016_df, demo_state_cols_2016_df], axis=1)
total_demo_state_2015_df = pd.concat([demo_state_2015_df, demo_state_cols_2015_df], axis=1)
total_demo_state_2014_df = pd.concat([demo_state_2014_df, demo_state_cols_2014_df], axis=1)
total_demo_state_2013_df = pd.concat([demo_state_2013_df, demo_state_cols_2013_df], axis=1)

total_demo_state_2013_df.head()
# Out:
#     Geography  Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race  \
# 0     Alabama                                               98.5
# 1      Alaska                                               92.1
# 2     Arizona                                               97.0
# 3    Arkansas                                               98.0
# 4  California                                               95.7
#
#    Total; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race  \
# 0                                                0.1
# 1                                                0.2
# 2                                                0.1
# 3                                                0.1
# 4                                                0.1
#
#    60 years and over; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race  \
# 0                                               99.2
# 1                                               97.6
# 2                                               99.0
# 3                                               98.9
# 4                                               98.1
#
#    60 years and over; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race  \
# 0                                                0.1
# 1                                                0.3
# 2                                                0.1
# 3                                                0.1
# 4                                                0.1
#
#    Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - White  \
# 0                                               69.3
# 1                                               66.9
# 2                                               79.2
# 3                                               78.3
# 4                                               62.3
#
#    Total; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - White  \
# 0                                                0.1
# 1                                                0.1
# 2                                                0.2
# 3                                                0.1
# 4                                                0.1
#
#    60 years and over; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - White  \
# 0                                               78.9
# 1                                               76.8
# 2                                               90.1
# 3                                               87.6
# 4                                               72.6
#
#    60 years and over; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - White  \
# 0                                                0.1
# 1                                                0.4
# 2                                                0.1
# 3                                                0.1
# 4                                                0.1
#
#    Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Black or African American  \
# 0                                               26.3
# 1                                                3.5
# 2                                                4.2
# 3                                               15.5
# 4                                                6.0
#
#                                               ...                                              \
# 0                                             ...
# 1                                             ...
# 2                                             ...
# 3                                             ...
# 4                                             ...
#
#    60 years and over; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Native Hawaiian and Other Pacific Islander  \
# 0                                                0.0
# 1                                                0.5
# 2                                                0.1
# 3                                                0.0
# 4                                                0.3
#
#    60 years and over; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - Native Hawaiian and Other Pacific Islander  \
# 0                                                0.1
# 1                                                0.1
# 2                                                0.1
# 3                                                0.1
# 4                                                0.1
#
#    Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Some other race  \
# 0                                                1.2
# 1                                                1.2
# 2                                                6.2
# 3                                                2.2
# 4                                               12.9
#
#    Total; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - Some other race  \
# 0                                                0.1
# 1                                                0.1
# 2                                                0.1
# 3                                                0.1
# 4                                                0.1
#
#    60 years and over; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Some other race  \
# 0                                                0.2
# 1                                                0.6
# 2                                                2.4
# 3                                                0.4
# 4                                                5.4
#
#    60 years and over; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - Some other race  \
# 0                                                0.1
# 1                                                0.2
# 2                                                0.1
# 3                                                0.1
# 4                                                0.1
#
#    Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races  \
# 0                                                1.5
# 1                                                7.9
# 2                                                3.0
# 3                                                2.0
# 4                                                4.3
#
#    Total; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races  \
# 0                                                0.1
# 1                                                0.2
# 2                                                0.1
# 3                                                0.1
# 4                                                0.1
#
#    60 years and over; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races  \
# 0                                                0.8
# 1                                                2.4
# 2                                                1.0
# 3                                                1.1
# 4                                                1.9
#
#    60 years and over; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races
# 0                                                0.1
# 1                                                0.3
# 2                                                0.1
# 3                                                0.1
# 4                                                0.1
#
# [5 rows x 33 columns]

# %%
total_demo_state_2013_df.columns
# Out:
# Index(['Geography',
#        'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race',
#        'Total; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race',
#        '60 years and over; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race',
#        '60 years and over; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race',
#        'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - White',
#        'Total; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - White',
#        '60 years and over; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - White',
#        '60 years and over; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - White',
#        'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Black or African American',
#        'Total; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - Black or African American',
#        '60 years and over; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Black or African American',
#        '60 years and over; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - Black or African American',
#        'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - American Indian and Alaska Native',
#        'Total; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - American Indian and Alaska Native',
#        '60 years and over; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - American Indian and Alaska Native',
#        '60 years and over; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - American Indian and Alaska Native',
#        'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Asian',
#        'Total; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - Asian',
#        '60 years and over; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Asian',
#        '60 years and over; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - Asian',
#        'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Native Hawaiian and Other Pacific Islander',
#        'Total; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - Native Hawaiian and Other Pacific Islander',
#        '60 years and over; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Native Hawaiian and Other Pacific Islander',
#        '60 years and over; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - Native Hawaiian and Other Pacific Islander',
#        'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Some other race',
#        'Total; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - Some other race',
#        '60 years and over; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Some other race',
#        '60 years and over; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - Some other race',
#        'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races',
#        'Total; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races',
#        '60 years and over; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races',
#        '60 years and over; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races'],
#       dtype='object')

# %%
total_demo_state_2017_df.columns
demo_cols_state_2017 = ['Geography',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - White',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Black or African American',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - American Indian and Alaska Native',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Asian',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Native Hawaiian and Other Pacific Islander',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Some other race',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races']
demo_cols_state_2017

total_demo_state_2016_df.columns
demo_cols_state_2016 = ['Geography',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - White',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Black or African American',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - American Indian and Alaska Native',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Asian',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Native Hawaiian and Other Pacific Islander',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Some other race',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races']
demo_cols_state_2016

total_demo_state_2015_df.columns
demo_cols_state_2015 = ['Geography',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - White',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Black or African American',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - American Indian and Alaska Native',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Asian',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Native Hawaiian and Other Pacific Islander',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Some other race',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races']
demo_cols_state_2015

total_demo_state_2014_df.columns
demo_cols_state_2014 = ['Geography',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - White',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Black or African American',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - American Indian and Alaska Native',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Asian',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Native Hawaiian and Other Pacific Islander',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Some other race',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races']
demo_cols_state_2014

total_demo_state_2013_df.columns
demo_cols_state_2013 = ['Geography',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - White',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Black or African American',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - American Indian and Alaska Native',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Asian',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Native Hawaiian and Other Pacific Islander',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Some other race',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races']
demo_cols_state_2013
# Out:
# ['Geography',
#  'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race',
#  'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - White',
#  'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Black or African American',
#  'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - American Indian and Alaska Native',
#  'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Asian',
#  'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Native Hawaiian and Other Pacific Islander',
#  'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Some other race',
#  'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races']

# %%
demo_state_2017_data = total_demo_state_2017_df[demo_cols_state_2017]
demo_state_2017_data.head()

demo_state_2016_data = total_demo_state_2016_df[demo_cols_state_2016]
demo_state_2016_data.head()

demo_state_2015_data = total_demo_state_2015_df[demo_cols_state_2015]
demo_state_2015_data.head()

demo_state_2014_data = total_demo_state_2014_df[demo_cols_state_2014]
demo_state_2014_data.head()

demo_state_2013_data = total_demo_state_2013_df[demo_cols_state_2013]
demo_state_2013_data.head()
# Out:
#     Geography  Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race  \
# 0     Alabama                                               98.5
# 1      Alaska                                               92.1
# 2     Arizona                                               97.0
# 3    Arkansas                                               98.0
# 4  California                                               95.7
#
#    Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - White  \
# 0                                               69.3
# 1                                               66.9
# 2                                               79.2
# 3                                               78.3
# 4                                               62.3
#
#    Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Black or African American  \
# 0                                               26.3
# 1                                                3.5
# 2                                                4.2
# 3                                               15.5
# 4                                                6.0
#
#    Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - American Indian and Alaska Native  \
# 0                                                0.5
# 1                                               14.1
# 2                                                4.4
# 3                                                0.6
# 4                                                0.8
#
#    Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Asian  \
# 0                                                1.2
# 1                                                5.4
# 2                                                2.8
# 3                                                1.3
# 4                                               13.3
#
#    Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Native Hawaiian and Other Pacific Islander  \
# 0                                                0.0
# 1                                                1.1
# 2                                                0.2
# 3                                                0.2
# 4                                                0.4
#
#    Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Some other race  \
# 0                                                1.2
# 1                                                1.2
# 2                                                6.2
# 3                                                2.2
# 4                                               12.9
#
#    Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races
# 0                                                1.5
# 1                                                7.9
# 2                                                3.0
# 3                                                2.0
# 4                                                4.3

# %%
demo_state_2017_data = demo_state_2013_data.rename(columns={'Geography': 'State',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race': 'One Race 2017',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - White': 'White 2017',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Black or African American': 'Black or African American 2017',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - American Indian and Alaska Native': 'American Indian and Alaska Native 2017',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Asian': 'Asian 2017',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Native Hawaiian and Other Pacific Islander': 'Native Hawaiian and Other Pacific Islander 2017',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Some other race': 'Some other race 2017',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races': 'Two or more races 2017'})
demo_state_2017_data.head()

demo_state_2016_data = demo_state_2016_data.rename(columns={'Geography': 'State',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race': 'One Race 2016',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - White': 'White 2016',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Black or African American': 'Black or African American 2016',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - American Indian and Alaska Native': 'American Indian and Alaska Native 2016',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Asian': 'Asian 2016',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Native Hawaiian and Other Pacific Islander': 'Native Hawaiian and Other Pacific Islander 2016',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Some other race': 'Some other race 2016',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races': 'Two or more races 2016'})
demo_state_2016_data.head()

demo_state_2015_data = demo_state_2015_data.rename(columns={'Geography': 'State',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race': 'One Race 2015',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - White': 'White 2015',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Black or African American': 'Black or African American 2015',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - American Indian and Alaska Native': 'American Indian and Alaska Native 2015',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Asian': 'Asian 2015',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Native Hawaiian and Other Pacific Islander': 'Native Hawaiian and Other Pacific Islander 2015',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Some other race': 'Some other race 2015',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races': 'Two or more races 2015'})
demo_state_2015_data.head()

demo_state_2014_data = demo_state_2014_data.rename(columns={'Geography': 'State',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race': 'One Race 2014',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - White': 'White 2014',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Black or African American': 'Black or African American 2014',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - American Indian and Alaska Native': 'American Indian and Alaska Native 2014',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Asian': 'Asian 2014',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Native Hawaiian and Other Pacific Islander': 'Native Hawaiian and Other Pacific Islander 2014',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Some other race': 'Some other race 2014',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races': 'Two or more races 2014'})
demo_state_2014_data.head()

demo_state_2013_data = demo_state_2013_data.rename(columns={'Geography': 'State',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race': 'One Race 2013',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - White': 'White 2013',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Black or African American': 'Black or African American 2013',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - American Indian and Alaska Native': 'American Indian and Alaska Native 2013',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Asian': 'Asian 2013',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Native Hawaiian and Other Pacific Islander': 'Native Hawaiian and Other Pacific Islander 2013',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Some other race': 'Some other race 2013',
       'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races': 'Two or more races 2013'})
demo_state_2013_data.head()
# Out:
#         State  One Race 2013  White 2013  Black or African American 2013  \
# 0     Alabama           98.5        69.3                            26.3
# 1      Alaska           92.1        66.9                             3.5
# 2     Arizona           97.0        79.2                             4.2
# 3    Arkansas           98.0        78.3                            15.5
# 4  California           95.7        62.3                             6.0
#
#    American Indian and Alaska Native 2013  Asian 2013  \
# 0                                     0.5         1.2
# 1                                    14.1         5.4
# 2                                     4.4         2.8
# 3                                     0.6         1.3
# 4                                     0.8        13.3
#
#    Native Hawaiian and Other Pacific Islander 2013  Some other race 2013  \
# 0                                              0.0                   1.2
# 1                                              1.1                   1.2
# 2                                              0.2                   6.2
# 3                                              0.2                   2.2
# 4                                              0.4                  12.9
#
#    Two or more races 2013
# 0                     1.5
# 1                     7.9
# 2                     3.0
# 3                     2.0
# 4                     4.3

# %%
total_demo_2013_2014_data = pd.merge(demo_state_2013_data, demo_state_2014_data, on=["State"])
total_demo_2013_2014_2015_data = pd.merge(total_demo_2013_2014_data, demo_state_2015_data, on=["State"])
total_demo_2013_2014_2015_2016_data = pd.merge(total_demo_2013_2014_2015_data, demo_state_2016_data, on=["State"])
total_demo_state_data = pd.merge(total_demo_2013_2014_2015_2016_data, demo_state_2017_data, on=["State"])

total_demo_state_data.head()
# Out:
#         State  One Race 2013  White 2013  Black or African American 2013  \
# 0     Alabama           98.5        69.3                            26.3
# 1      Alaska           92.1        66.9                             3.5
# 2     Arizona           97.0        79.2                             4.2
# 3    Arkansas           98.0        78.3                            15.5
# 4  California           95.7        62.3                             6.0
#
#    American Indian and Alaska Native 2013  Asian 2013  \
# 0                                     0.5         1.2
# 1                                    14.1         5.4
# 2                                     4.4         2.8
# 3                                     0.6         1.3
# 4                                     0.8        13.3
#
#    Native Hawaiian and Other Pacific Islander 2013  Some other race 2013  \
# 0                                              0.0                   1.2
# 1                                              1.1                   1.2
# 2                                              0.2                   6.2
# 3                                              0.2                   2.2
# 4                                              0.4                  12.9
#
#    Two or more races 2013  One Race 2014           ...            \
# 0                     1.5           98.4           ...
# 1                     7.9           92.0           ...
# 2                     3.0           96.9           ...
# 3                     2.0           98.0           ...
# 4                     4.3           95.5           ...
#
#    Some other race 2016  Two or more races 2016  One Race 2017  White 2017  \
# 0                   1.3                     1.8           98.5        69.3
# 1                   1.3                     8.5           92.1        66.9
# 2                   7.0                     3.3           97.0        79.2
# 3                   2.3                     2.2           98.0        78.3
# 4                  13.3                     4.6           95.7        62.3
#
#    Black or African American 2017  American Indian and Alaska Native 2017  \
# 0                            26.3                                     0.5
# 1                             3.5                                    14.1
# 2                             4.2                                     4.4
# 3                            15.5                                     0.6
# 4                             6.0                                     0.8
#
#    Asian 2017  Native Hawaiian and Other Pacific Islander 2017  \
# 0         1.2                                              0.0
# 1         5.4                                              1.1
# 2         2.8                                              0.2
# 3         1.3                                              0.2
# 4        13.3                                              0.4
#
#    Some other race 2017  Two or more races 2017
# 0                   1.2                     1.5
# 1                   1.2                     7.9
# 2                   6.2                     3.0
# 3                   2.2                     2.0
# 4                  12.9                     4.3
#
# [5 rows x 41 columns]
